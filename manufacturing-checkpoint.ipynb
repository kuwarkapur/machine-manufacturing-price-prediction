# %%
import pandas as pd
train=pd.read_csv('Train.csv')
test=pd.read_csv('test (2).csv')
# Out:
# C:\Users\Kuwar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (13,39,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
train.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
# 3                     NaN          NaN   NaN             NaN          NaN
# 4                     NaN          NaN   NaN             NaN          NaN
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0              NaN        NaN             NaN          Standard
# 1              NaN        NaN             NaN          Standard
# 2              NaN        NaN             NaN               NaN
# 3              NaN        NaN             NaN               NaN
# 4              NaN        NaN             NaN               NaN
#
#   Steering_Controls
# 0      Conventional
# 1      Conventional
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 53 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401125 entries, 0 to 401124
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   401125 non-null  int64
#  1   SalePrice                 401125 non-null  int64
#  2   MachineID                 401125 non-null  int64
#  3   ModelID                   401125 non-null  int64
#  4   datasource                401125 non-null  int64
#  5   auctioneerID              380989 non-null  float64
#  6   YearMade                  401125 non-null  int64
#  7   MachineHoursCurrentMeter  142765 non-null  float64
#  8   UsageBand                 69639 non-null   object
#  9   saledate                  401125 non-null  object
#  10  fiModelDesc               401125 non-null  object
#  11  fiBaseModel               401125 non-null  object
#  12  fiSecondaryDesc           263934 non-null  object
#  13  fiModelSeries             56908 non-null   object
#  14  fiModelDescriptor         71919 non-null   object
#  15  ProductSize               190350 non-null  object
#  16  fiProductClassDesc        401125 non-null  object
#  17  state                     401125 non-null  object
#  18  ProductGroup              401125 non-null  object
#  19  ProductGroupDesc          401125 non-null  object
#  20  Drive_System              104361 non-null  object
#  21  Enclosure                 400800 non-null  object
#  22  Forks                     192077 non-null  object
#  23  Pad_Type                  79134 non-null   object
#  24  Ride_Control              148606 non-null  object
#  25  Stick                     79134 non-null   object
#  26  Transmission              183230 non-null  object
#  27  Turbocharged              79134 non-null   object
#  28  Blade_Extension           25219 non-null   object
#  29  Blade_Width               25219 non-null   object
#  30  Enclosure_Type            25219 non-null   object
#  31  Engine_Horsepower         25219 non-null   object
#  32  Hydraulics                320570 non-null  object
#  33  Pushblock                 25219 non-null   object
#  34  Ripper                    104137 non-null  object
#  35  Scarifier                 25230 non-null   object
#  36  Tip_Control               25219 non-null   object
#  37  Tire_Size                 94718 non-null   object
#  38  Coupler                   213952 non-null  object
#  39  Coupler_System            43458 non-null   object
#  40  Grouser_Tracks            43362 non-null   object
#  41  Hydraulics_Flow           43362 non-null   object
#  42  Track_Type                99153 non-null   object
#  43  Undercarriage_Pad_Width   99872 non-null   object
#  44  Stick_Length              99218 non-null   object
#  45  Thumb                     99288 non-null   object
#  46  Pattern_Changer           99218 non-null   object
#  47  Grouser_Type              99153 non-null   object
#  48  Backhoe_Mounting          78672 non-null   object
#  49  Blade_Type                79833 non-null   object
#  50  Travel_Controls           79834 non-null   object
#  51  Differential_Type         69411 non-null   object
#  52  Steering_Controls         69369 non-null   object
# dtypes: float64(2), int64(6), object(45)
# memory usage: 162.2+ MB

# %%
train.describe()
# Out:
#             SalesID      SalePrice     MachineID        ModelID  \
# count  4.011250e+05  401125.000000  4.011250e+05  401125.000000
# mean   1.919713e+06   31099.712848  1.217903e+06    6889.702980
# std    9.090215e+05   23036.898502  4.409920e+05    6221.777842
# min    1.139246e+06    4750.000000  0.000000e+00      28.000000
# 25%    1.418371e+06   14500.000000  1.088697e+06    3259.000000
# 50%    1.639422e+06   24000.000000  1.279490e+06    4604.000000
# 75%    2.242707e+06   40000.000000  1.468067e+06    8724.000000
# max    6.333342e+06  142000.000000  2.486330e+06   37198.000000
#
#           datasource   auctioneerID       YearMade  MachineHoursCurrentMeter
# count  401125.000000  380989.000000  401125.000000              1.427650e+05
# mean      134.665810       6.556040    1899.156901              3.457955e+03
# std         8.962237      16.976779     291.797469              2.759026e+04
# min       121.000000       0.000000    1000.000000              0.000000e+00
# 25%       132.000000       1.000000    1985.000000              0.000000e+00
# 50%       132.000000       2.000000    1995.000000              0.000000e+00
# 75%       136.000000       4.000000    2000.000000              3.025000e+03
# max       172.000000      99.000000    2013.000000              2.483300e+06

# %%
null=dict(train.isnull().sum())

# %%
train.isnull().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    258360
# UsageBand                   331486
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             137191
# fiModelSeries               344217
# fiModelDescriptor           329206
# ProductSize                 210775
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                296764
# Enclosure                      325
# Forks                       209048
# Pad_Type                    321991
# Ride_Control                252519
# Stick                       321991
# Transmission                217895
# Turbocharged                321991
# Blade_Extension             375906
# Blade_Width                 375906
# Enclosure_Type              375906
# Engine_Horsepower           375906
# Hydraulics                   80555
# Pushblock                   375906
# Ripper                      296988
# Scarifier                   375895
# Tip_Control                 375906
# Tire_Size                   306407
# Coupler                     187173
# Coupler_System              357667
# Grouser_Tracks              357763
# Hydraulics_Flow             357763
# Track_Type                  301972
# Undercarriage_Pad_Width     301253
# Stick_Length                301907
# Thumb                       301837
# Pattern_Changer             301907
# Grouser_Type                301972
# Backhoe_Mounting            322453
# Blade_Type                  321292
# Travel_Controls             321291
# Differential_Type           331714
# Steering_Controls           331756
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401125 entries, 0 to 401124
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   401125 non-null  int64
#  1   SalePrice                 401125 non-null  int64
#  2   MachineID                 401125 non-null  int64
#  3   ModelID                   401125 non-null  int64
#  4   datasource                401125 non-null  int64
#  5   auctioneerID              380989 non-null  float64
#  6   YearMade                  401125 non-null  int64
#  7   MachineHoursCurrentMeter  142765 non-null  float64
#  8   UsageBand                 69639 non-null   object
#  9   saledate                  401125 non-null  object
#  10  fiModelDesc               401125 non-null  object
#  11  fiBaseModel               401125 non-null  object
#  12  fiSecondaryDesc           263934 non-null  object
#  13  fiModelSeries             56908 non-null   object
#  14  fiModelDescriptor         71919 non-null   object
#  15  ProductSize               190350 non-null  object
#  16  fiProductClassDesc        401125 non-null  object
#  17  state                     401125 non-null  object
#  18  ProductGroup              401125 non-null  object
#  19  ProductGroupDesc          401125 non-null  object
#  20  Drive_System              104361 non-null  object
#  21  Enclosure                 400800 non-null  object
#  22  Forks                     192077 non-null  object
#  23  Pad_Type                  79134 non-null   object
#  24  Ride_Control              148606 non-null  object
#  25  Stick                     79134 non-null   object
#  26  Transmission              183230 non-null  object
#  27  Turbocharged              79134 non-null   object
#  28  Blade_Extension           25219 non-null   object
#  29  Blade_Width               25219 non-null   object
#  30  Enclosure_Type            25219 non-null   object
#  31  Engine_Horsepower         25219 non-null   object
#  32  Hydraulics                320570 non-null  object
#  33  Pushblock                 25219 non-null   object
#  34  Ripper                    104137 non-null  object
#  35  Scarifier                 25230 non-null   object
#  36  Tip_Control               25219 non-null   object
#  37  Tire_Size                 94718 non-null   object
#  38  Coupler                   213952 non-null  object
#  39  Coupler_System            43458 non-null   object
#  40  Grouser_Tracks            43362 non-null   object
#  41  Hydraulics_Flow           43362 non-null   object
#  42  Track_Type                99153 non-null   object
#  43  Undercarriage_Pad_Width   99872 non-null   object
#  44  Stick_Length              99218 non-null   object
#  45  Thumb                     99288 non-null   object
#  46  Pattern_Changer           99218 non-null   object
#  47  Grouser_Type              99153 non-null   object
#  48  Backhoe_Mounting          78672 non-null   object
#  49  Blade_Type                79833 non-null   object
#  50  Travel_Controls           79834 non-null   object
#  51  Differential_Type         69411 non-null   object
#  52  Steering_Controls         69369 non-null   object
# dtypes: float64(2), int64(6), object(45)
# memory usage: 162.2+ MB

# %%
new_col=train.select_dtypes(include=object).columns
new_col
# Out:
# Index(['UsageBand', 'saledate', 'fiModelDesc', 'fiBaseModel',
#        'fiSecondaryDesc', 'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls'],
#       dtype='object')

# %%
for i in new_col:
    print(train[i])
# Out:
# 0            Low
# 1            Low
# 2           High
# 3           High
# 4         Medium
#            ...
# 401120       NaN
# 401121       NaN
# 401122       NaN
# 401123       NaN
# 401124       NaN
# Name: UsageBand, Length: 401125, dtype: object
# 0         11/16/2006 0:00
# 1          3/26/2004 0:00
# 2          2/26/2004 0:00
# 3          5/19/2011 0:00
# 4          7/23/2009 0:00
#                ...
# 401120     11/2/2011 0:00
# 401121     11/2/2011 0:00
# 401122     11/2/2011 0:00
# 401123    10/25/2011 0:00
# 401124    10/25/2011 0:00
# Name: saledate, Length: 401125, dtype: object
# 0             521D
# 1           950FII
# 2              226
# 3         PC120-6E
# 4             S175
#             ...
# 401120       35NX2
# 401121       35NX2
# 401122       35NX2
# 401123        30NX
# 401124        30NX
# Name: fiModelDesc, Length: 401125, dtype: object
# 0           521
# 1           950
# 2           226
# 3         PC120
# 4          S175
#           ...
# 401120       35
# 401121       35
# 401122       35
# 401123       30
# 401124       30
# Name: fiBaseModel, Length: 401125, dtype: object
# 0           D
# 1           F
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120     NX
# 401121     NX
# 401122     NX
# 401123     NX
# 401124     NX
# Name: fiSecondaryDesc, Length: 401125, dtype: object
# 0         NaN
# 1          II
# 2         NaN
# 3         -6E
# 4         NaN
#          ...
# 401120      2
# 401121      2
# 401122      2
# 401123    NaN
# 401124    NaN
# Name: fiModelSeries, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: fiModelDescriptor, Length: 401125, dtype: object
# 0            NaN
# 1         Medium
# 2            NaN
# 3          Small
# 4            NaN
#            ...
# 401120      Mini
# 401121      Mini
# 401122      Mini
# 401123      Mini
# 401124      Mini
# Name: ProductSize, Length: 401125, dtype: object
# 0                  Wheel Loader - 110.0 to 120.0 Horsepower
# 1                  Wheel Loader - 150.0 to 175.0 Horsepower
# 2         Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...
# 3         Hydraulic Excavator, Track - 12.0 to 14.0 Metr...
# 4         Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...
#                                 ...
# 401120    Hydraulic Excavator, Track - 3.0 to 4.0 Metric...
# 401121    Hydraulic Excavator, Track - 3.0 to 4.0 Metric...
# 401122    Hydraulic Excavator, Track - 3.0 to 4.0 Metric...
# 401123    Hydraulic Excavator, Track - 2.0 to 3.0 Metric...
# 401124    Hydraulic Excavator, Track - 2.0 to 3.0 Metric...
# Name: fiProductClassDesc, Length: 401125, dtype: object
# 0                Alabama
# 1         North Carolina
# 2               New York
# 3                  Texas
# 4               New York
#                ...
# 401120          Maryland
# 401121          Maryland
# 401122          Maryland
# 401123           Florida
# 401124           Florida
# Name: state, Length: 401125, dtype: object
# 0          WL
# 1          WL
# 2         SSL
# 3         TEX
# 4         SSL
#          ...
# 401120    TEX
# 401121    TEX
# 401122    TEX
# 401123    TEX
# 401124    TEX
# Name: ProductGroup, Length: 401125, dtype: object
# 0               Wheel Loader
# 1               Wheel Loader
# 2         Skid Steer Loaders
# 3           Track Excavators
# 4         Skid Steer Loaders
#                  ...
# 401120      Track Excavators
# 401121      Track Excavators
# 401122      Track Excavators
# 401123      Track Excavators
# 401124      Track Excavators
# Name: ProductGroupDesc, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Drive_System, Length: 401125, dtype: object
# 0         EROPS w AC
# 1         EROPS w AC
# 2              OROPS
# 3         EROPS w AC
# 4              EROPS
#              ...
# 401120         EROPS
# 401121         EROPS
# 401122         EROPS
# 401123         EROPS
# 401124         EROPS
# Name: Enclosure, Length: 401125, dtype: object
# 0         None or Unspecified
# 1         None or Unspecified
# 2         None or Unspecified
# 3                         NaN
# 4         None or Unspecified
#                  ...
# 401120                    NaN
# 401121                    NaN
# 401122                    NaN
# 401123                    NaN
# 401124                    NaN
# Name: Forks, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Pad_Type, Length: 401125, dtype: object
# 0         None or Unspecified
# 1         None or Unspecified
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120                    NaN
# 401121                    NaN
# 401122                    NaN
# 401123                    NaN
# 401124                    NaN
# Name: Ride_Control, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Stick, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Transmission, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Turbocharged, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Blade_Extension, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Blade_Width, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Enclosure_Type, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Engine_Horsepower, Length: 401125, dtype: object
# 0           2 Valve
# 1           2 Valve
# 2         Auxiliary
# 3           2 Valve
# 4         Auxiliary
#             ...
# 401120    Auxiliary
# 401121     Standard
# 401122    Auxiliary
# 401123     Standard
# 401124     Standard
# Name: Hydraulics, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Pushblock, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Ripper, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Scarifier, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Tip_Control, Length: 401125, dtype: object
# 0         None or Unspecified
# 1                        23.5
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120                    NaN
# 401121                    NaN
# 401122                    NaN
# 401123                    NaN
# 401124                    NaN
# Name: Tire_Size, Length: 401125, dtype: object
# 0         None or Unspecified
# 1         None or Unspecified
# 2         None or Unspecified
# 3         None or Unspecified
# 4         None or Unspecified
#                  ...
# 401120    None or Unspecified
# 401121    None or Unspecified
# 401122    None or Unspecified
# 401123    None or Unspecified
# 401124    None or Unspecified
# Name: Coupler, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2         None or Unspecified
# 3                         NaN
# 4         None or Unspecified
#                  ...
# 401120                    NaN
# 401121                    NaN
# 401122                    NaN
# 401123                    NaN
# 401124                    NaN
# Name: Coupler_System, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2         None or Unspecified
# 3                         NaN
# 4         None or Unspecified
#                  ...
# 401120                    NaN
# 401121                    NaN
# 401122                    NaN
# 401123                    NaN
# 401124                    NaN
# Name: Grouser_Tracks, Length: 401125, dtype: object
# 0              NaN
# 1              NaN
# 2         Standard
# 3              NaN
# 4         Standard
#             ...
# 401120         NaN
# 401121         NaN
# 401122         NaN
# 401123         NaN
# 401124         NaN
# Name: Hydraulics_Flow, Length: 401125, dtype: object
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 401120    Steel
# 401121    Steel
# 401122    Steel
# 401123    Steel
# 401124    Steel
# Name: Track_Type, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120    None or Unspecified
# 401121    None or Unspecified
# 401122    None or Unspecified
# 401123    None or Unspecified
# 401124    None or Unspecified
# Name: Undercarriage_Pad_Width, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120    None or Unspecified
# 401121    None or Unspecified
# 401122    None or Unspecified
# 401123    None or Unspecified
# 401124    None or Unspecified
# Name: Stick_Length, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120    None or Unspecified
# 401121    None or Unspecified
# 401122    None or Unspecified
# 401123    None or Unspecified
# 401124    None or Unspecified
# Name: Thumb, Length: 401125, dtype: object
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 401120    None or Unspecified
# 401121    None or Unspecified
# 401122    None or Unspecified
# 401123    None or Unspecified
# 401124    None or Unspecified
# Name: Pattern_Changer, Length: 401125, dtype: object
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 401120    Double
# 401121    Double
# 401122    Double
# 401123    Double
# 401124    Double
# Name: Grouser_Type, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Backhoe_Mounting, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Blade_Type, Length: 401125, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 401120    NaN
# 401121    NaN
# 401122    NaN
# 401123    NaN
# 401124    NaN
# Name: Travel_Controls, Length: 401125, dtype: object
# 0         Standard
# 1         Standard
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 401120         NaN
# 401121         NaN
# 401122         NaN
# 401123         NaN
# 401124         NaN
# Name: Differential_Type, Length: 401125, dtype: object
# 0         Conventional
# 1         Conventional
# 2                  NaN
# 3                  NaN
# 4                  NaN
#               ...
# 401120             NaN
# 401121             NaN
# 401122             NaN
# 401123             NaN
# 401124             NaN
# Name: Steering_Controls, Length: 401125, dtype: object

# %%
for i in (new_col):
    print(i)
    train[i]=train[i].fillna(train[i].mode()[0])
# Out:
# UsageBand
# saledate
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
train.isnull().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    258360
# UsageBand                        0
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc                  0
# fiModelSeries                    0
# fiModelDescriptor                0
# ProductSize                      0
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                     0
# Enclosure                        0
# Forks                            0
# Pad_Type                         0
# Ride_Control                     0
# Stick                            0
# Transmission                     0
# Turbocharged                     0
# Blade_Extension                  0
# Blade_Width                      0
# Enclosure_Type                   0
# Engine_Horsepower                0
# Hydraulics                       0
# Pushblock                        0
# Ripper                           0
# Scarifier                        0
# Tip_Control                      0
# Tire_Size                        0
# Coupler                          0
# Coupler_System                   0
# Grouser_Tracks                   0
# Hydraulics_Flow                  0
# Track_Type                       0
# Undercarriage_Pad_Width          0
# Stick_Length                     0
# Thumb                            0
# Pattern_Changer                  0
# Grouser_Type                     0
# Backhoe_Mounting                 0
# Blade_Type                       0
# Travel_Controls                  0
# Differential_Type                0
# Steering_Controls                0
# dtype: int64

# %%
for i in ['auctioneerID','MachineHoursCurrentMeter']:
    train[i]=train[i].mean()

# %%
train.isnull().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
# YearMade                    0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# saledate                    0
# fiModelDesc                 0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# fiModelDescriptor           0
# ProductSize                 0
# fiProductClassDesc          0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11573 entries, 0 to 11572
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   11573 non-null  int64
#  1   MachineID                 11573 non-null  int64
#  2   ModelID                   11573 non-null  int64
#  3   datasource                11573 non-null  int64
#  4   auctioneerID              11573 non-null  int64
#  5   YearMade                  11573 non-null  int64
#  6   MachineHoursCurrentMeter  4739 non-null   float64
#  7   UsageBand                 4031 non-null   object
#  8   saledate                  11573 non-null  object
#  9   fiModelDesc               11573 non-null  object
#  10  fiBaseModel               11573 non-null  object
#  11  fiSecondaryDesc           8037 non-null   object
#  12  fiModelSeries             1759 non-null   object
#  13  fiModelDescriptor         2897 non-null   object
#  14  ProductSize               5743 non-null   object
#  15  fiProductClassDesc        11573 non-null  object
#  16  state                     11573 non-null  object
#  17  ProductGroup              11573 non-null  object
#  18  ProductGroupDesc          11573 non-null  object
#  19  Drive_System              2726 non-null   object
#  20  Enclosure                 11564 non-null  object
#  21  Forks                     5638 non-null   object
#  22  Pad_Type                  1962 non-null   object
#  23  Ride_Control              4122 non-null   object
#  24  Stick                     1962 non-null   object
#  25  Transmission              4777 non-null   object
#  26  Turbocharged              1962 non-null   object
#  27  Blade_Extension           764 non-null    object
#  28  Blade_Width               764 non-null    object
#  29  Enclosure_Type            764 non-null    object
#  30  Engine_Horsepower         764 non-null    object
#  31  Hydraulics                9563 non-null   object
#  32  Pushblock                 764 non-null    object
#  33  Ripper                    2808 non-null   object
#  34  Scarifier                 764 non-null    object
#  35  Tip_Control               764 non-null    object
#  36  Tire_Size                 2920 non-null   object
#  37  Coupler                   6727 non-null   object
#  38  Coupler_System            1516 non-null   object
#  39  Grouser_Tracks            1513 non-null   object
#  40  Hydraulics_Flow           1513 non-null   object
#  41  Track_Type                3040 non-null   object
#  42  Undercarriage_Pad_Width   3044 non-null   object
#  43  Stick_Length              3043 non-null   object
#  44  Thumb                     3044 non-null   object
#  45  Pattern_Changer           3043 non-null   object
#  46  Grouser_Type              3040 non-null   object
#  47  Backhoe_Mounting          2040 non-null   object
#  48  Blade_Type                2042 non-null   object
#  49  Travel_Controls           2043 non-null   object
#  50  Differential_Type         2153 non-null   object
#  51  Steering_Controls         2153 non-null   object
# dtypes: float64(1), int64(6), object(45)
# memory usage: 4.6+ MB

# %%
def preprocess(DF):
    NULL=dict(DF.isnull().sum())
    for i in DF.columns:
        if (NULL[i])>0.70*len(DF):
            DF=DF.drop(i,axis=1)
    new_col=DF.select_dtypes(include=object).columns
    new_col
    for i in (new_col):
        DF[i]=DF[i].fillna(DF[i].mode()[0])
        new_col1=DF.select_dtypes(include=float).columns
    for i in (new_col1):
        DF[i]=DF[i].fillna(DF[i].mean())
    return DF

# %%
test_new=preprocess(test)
train_new=preprocess(train)

# %%
print(len(test_new.columns))
print(len(train_new.columns))
# Out:
# 23
# 23

# %%
test_new=test_new.drop('UsageBand',axis=1)

# %%
new_col=train_new.select_dtypes(include=object).columns
for i in new_col:
    print(train_new[i].value_counts())
# Out:
# 2/16/2009 0:00    1932
# 2/15/2011 0:00    1352
# 2/19/2008 0:00    1300
# 2/15/2010 0:00    1219
# 2/11/2008 0:00    1100
#                   ...
# 5/4/1994 0:00        1
# 5/12/2001 0:00       1
# 8/31/2009 0:00       1
# 1/7/2011 0:00        1
# 1/31/2006 0:00       1
# Name: saledate, Length: 3919, dtype: int64
# 310G         5039
# 416C         4869
# 580K         4315
# 310E         4233
# 140G         4083
#              ...
# 6000B           1
# LS2650CII       1
# PC270LL7        1
# PC40-3          1
# 2SDK6           1
# Name: fiModelDesc, Length: 4999, dtype: int64
# 580          19798
# 310          17354
# D6           13110
# 416          12687
# D5            9342
#              ...
# FH31             1
# X341             1
# R50              1
# SOLAR 030        1
# WA90             1
# Name: fiBaseModel, Length: 1950, dtype: int64
# C                180426
# B                 39203
# G                 36424
# H                 24050
# E                 21048
#                   ...
# EW                    1
# 5                     1
#  MSR SPIN ACE         1
# LD                    1
# M                     1
# Name: fiSecondaryDesc, Length: 175, dtype: int64
# Medium            273049
# Large / Medium     49678
# Small              26494
# Mini               24840
# Large              20975
# Compact             6089
# Name: ProductSize, dtype: int64
# Backhoe Loader - 14.0 to 15.0 Ft Standard Digging Depth             56166
# Track Type Tractor, Dozer - 20.0 to 75.0 Horsepower                 17788
# Wheel Loader - 150.0 to 175.0 Horsepower                            15114
# Track Type Tractor, Dozer - 85.0 to 105.0 Horsepower                14731
# Hydraulic Excavator, Track - 21.0 to 24.0 Metric Tons               13323
#                                                                     ...
# Hydraulic Excavator, Track - Unidentified (Compact Construction)       38
# Wheel Loader - 1000.0 + Horsepower                                     25
# Hydraulic Excavator, Track - 150.0 to 300.0 Metric Tons                21
# Hydraulic Excavator, Track - 300.0 + Metric Tons                        1
# Motorgrader - Unidentified                                              1
# Name: fiProductClassDesc, Length: 74, dtype: int64
# Florida           63944
# Texas             51682
# California        29019
# Washington        15955
# Georgia           14309
# Maryland          12965
# Mississippi       12961
# Ohio              12190
# Colorado          11254
# Illinois          11209
# New Jersey        10882
# North Carolina    10404
# Tennessee         10027
# Alabama            9997
# Pennsylvania       9941
# South Carolina     9794
# Arizona            9173
# New York           8604
# Connecticut        8128
# Minnesota          7734
# Missouri           6961
# Nevada             6693
# Louisiana          6450
# Kentucky           5278
# Maine              5095
# Indiana            4086
# Arkansas           3869
# New Mexico         3529
# Utah               2895
# Unspecified        2801
# New Hampshire      2724
# Wisconsin          2668
# Virginia           2288
# Idaho              2018
# Oregon             1775
# Michigan           1763
# Wyoming            1662
# Montana            1327
# Oklahoma           1311
# Iowa               1215
# West Virginia       746
# Nebraska            722
# Kansas              659
# Delaware            509
# Alaska              430
# North Dakota        410
# Massachusetts       328
# Vermont             300
# South Dakota        203
# Hawaii              118
# Rhode Island         82
# Puerto Rico          36
# Washington DC         2
# Name: state, dtype: int64
# TEX    101167
# TTT     80520
# BL      79415
# WL      71046
# SSL     43488
# MG      25489
# Name: ProductGroup, dtype: int64
# Track Excavators       101167
# Track Type Tractors     80520
# Backhoe Loaders         79415
# Wheel Loader            71046
# Skid Steer Loaders      43488
# Motor Graders           25489
# Name: ProductGroupDesc, dtype: int64
# OROPS                  174257
# EROPS                  139026
# EROPS w AC              87820
# EROPS AC                   17
# NO ROPS                     3
# None or Unspecified         2
# Name: Enclosure, dtype: int64
# None or Unspecified    387348
# Yes                     13777
# Name: Forks, dtype: int64
# No                     330204
# None or Unspecified     63116
# Yes                      7805
# Name: Ride_Control, dtype: int64
# Standard               358223
# None or Unspecified     23147
# Powershift              11731
# Powershuttle             4244
# Hydrostatic              3204
# Direct Drive              418
# Autoshift                 114
# AutoShift                  44
# Name: Transmission, dtype: int64
# 2 Valve                221959
# Standard               104423
# Auxiliary               40737
# Base + 1 Function       24770
# 3 Valve                  5622
# 4 Valve                  2960
# Base + 3 Function         299
# Base + 2 Function         127
# Base + 5 Function          89
# Base + 4 Function          76
# Base + 6 Function          53
# None or Unspecified        10
# Name: Hydraulics, dtype: int64
# None or Unspecified    371755
# Manual                  23301
# Hydraulic                6069
# Name: Coupler, dtype: int64

# %%
new_col=train_new.select_dtypes(include=object).columns
new_col1=test_new.select_dtypes(include=object).columns
print(len(new_col))
print(len(new_col1))
# Out:
# 15
# 15

# %%
from sklearn.preprocessing import LabelEncoder
lr=LabelEncoder()
for i in new_col:
    train_new[i]=lr.fit_transform(train_new[i])
    test_new[i]=lr.fit_transform(test_new[i])

# %%
train_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401125 entries, 0 to 401124
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   401125 non-null  int64
#  1   SalePrice                 401125 non-null  int64
#  2   MachineID                 401125 non-null  int64
#  3   ModelID                   401125 non-null  int64
#  4   datasource                401125 non-null  int64
#  5   auctioneerID              401125 non-null  float64
#  6   YearMade                  401125 non-null  int64
#  7   MachineHoursCurrentMeter  401125 non-null  float64
#  8   saledate                  401125 non-null  int32
#  9   fiModelDesc               401125 non-null  int32
#  10  fiBaseModel               401125 non-null  int32
#  11  fiSecondaryDesc           401125 non-null  int32
#  12  ProductSize               401125 non-null  int32
#  13  fiProductClassDesc        401125 non-null  int32
#  14  state                     401125 non-null  int32
#  15  ProductGroup              401125 non-null  int32
#  16  ProductGroupDesc          401125 non-null  int32
#  17  Enclosure                 401125 non-null  int32
#  18  Forks                     401125 non-null  int32
#  19  Ride_Control              401125 non-null  int32
#  20  Transmission              401125 non-null  int32
#  21  Hydraulics                401125 non-null  int32
#  22  Coupler                   401125 non-null  int32
# dtypes: float64(2), int32(15), int64(6)
# memory usage: 47.4 MB

# %%
test_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11573 entries, 0 to 11572
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   11573 non-null  int64
#  1   MachineID                 11573 non-null  int64
#  2   ModelID                   11573 non-null  int64
#  3   datasource                11573 non-null  int64
#  4   auctioneerID              11573 non-null  int64
#  5   YearMade                  11573 non-null  int64
#  6   MachineHoursCurrentMeter  11573 non-null  float64
#  7   saledate                  11573 non-null  int32
#  8   fiModelDesc               11573 non-null  int32
#  9   fiBaseModel               11573 non-null  int32
#  10  fiSecondaryDesc           11573 non-null  int32
#  11  ProductSize               11573 non-null  int32
#  12  fiProductClassDesc        11573 non-null  int32
#  13  state                     11573 non-null  int32
#  14  ProductGroup              11573 non-null  int32
#  15  ProductGroupDesc          11573 non-null  int32
#  16  Enclosure                 11573 non-null  int32
#  17  Forks                     11573 non-null  int32
#  18  Ride_Control              11573 non-null  int32
#  19  Transmission              11573 non-null  int32
#  20  Hydraulics                11573 non-null  int32
#  21  Coupler                   11573 non-null  int32
# dtypes: float64(1), int32(15), int64(6)
# memory usage: 1.3 MB

# %%
train_new.corr()
# Out:
#                            SalesID  SalePrice  MachineID   ModelID  \
# SalesID                   1.000000   0.010725   0.286812  0.150199
# SalePrice                 0.010725   1.000000  -0.224854 -0.042125
# MachineID                 0.286812  -0.224854   1.000000  0.160591
# ModelID                   0.150199  -0.042125   0.160591  1.000000
# datasource                0.788917   0.015122   0.327118  0.091757
# auctioneerID             -0.021466  -0.045860   0.007264 -0.019284
# YearMade                  0.001701   0.156453  -0.060384 -0.049762
# MachineHoursCurrentMeter  0.002498   0.008583  -0.003089 -0.004111
# saledate                  0.030741  -0.018850   0.017729 -0.008423
# fiModelDesc               0.084880   0.008044   0.076119  0.198127
# fiBaseModel               0.094806  -0.002086   0.081397  0.211553
# fiSecondaryDesc           0.046170   0.129341   0.051753 -0.027190
# ProductSize              -0.002871  -0.165225  -0.000657  0.085666
# fiProductClassDesc       -0.000780   0.135842  -0.031352 -0.006304
# state                     0.017688  -0.018149   0.027465 -0.016361
# ProductGroup              0.015079   0.235409  -0.046519 -0.009325
# ProductGroupDesc          0.015079   0.235409  -0.046519 -0.009325
# Enclosure                -0.002230  -0.185837   0.009796 -0.003698
# Forks                     0.035118   0.046784  -0.042936 -0.014144
# Ride_Control              0.025605   0.150367  -0.003647 -0.044937
# Transmission              0.043989  -0.159736   0.078562 -0.000389
# Hydraulics               -0.002291  -0.020710   0.011942  0.158268
# Coupler                  -0.043327  -0.081313   0.099875 -0.039101
#
#                           datasource  auctioneerID  YearMade  \
# SalesID                     0.788917     -0.021466  0.001701
# SalePrice                   0.015122     -0.045860  0.156453
# MachineID                   0.327118      0.007264 -0.060384
# ModelID                     0.091757     -0.019284 -0.049762
# datasource                  1.000000     -0.018784  0.067088
# auctioneerID               -0.018784      1.000000 -0.017054
# YearMade                    0.067088     -0.017054  1.000000
# MachineHoursCurrentMeter    0.005883      0.015406 -0.007661
# saledate                    0.032055     -0.007317 -0.009810
# fiModelDesc                 0.024017     -0.015672 -0.134185
# fiBaseModel                 0.029658     -0.017159 -0.130634
# fiSecondaryDesc             0.051388     -0.020012 -0.018897
# ProductSize                -0.028632     -0.002601 -0.034996
# fiProductClassDesc          0.001438      0.004856 -0.020429
# state                       0.017481      0.013784 -0.015067
# ProductGroup                0.007024     -0.012004 -0.038945
# ProductGroupDesc            0.007024     -0.012004 -0.038945
# Enclosure                  -0.000535      0.017562  0.052592
# Forks                       0.043860     -0.008949  0.025674
# Ride_Control                0.038444     -0.010610  0.013150
# Transmission                0.056560     -0.025735  0.021947
# Hydraulics                 -0.039396     -0.006920 -0.071217
# Coupler                     0.007262      0.026056 -0.028607
#
#                           MachineHoursCurrentMeter  saledate  fiModelDesc  \
# SalesID                                   0.002498  0.030741     0.084880
# SalePrice                                 0.008583 -0.018850     0.008044
# MachineID                                -0.003089  0.017729     0.076119
# ModelID                                  -0.004111 -0.008423     0.198127
# datasource                                0.005883  0.032055     0.024017
# auctioneerID                              0.015406 -0.007317    -0.015672
# YearMade                                 -0.007661 -0.009810    -0.134185
# MachineHoursCurrentMeter                  1.000000 -0.001830     0.000892
# saledate                                 -0.001830  1.000000    -0.013514
# fiModelDesc                               0.000892 -0.013514     1.000000
# fiBaseModel                               0.000035 -0.014021     0.992610
# fiSecondaryDesc                          -0.000659  0.007037     0.001991
# ProductSize                              -0.008166 -0.019603    -0.031372
# fiProductClassDesc                        0.006541  0.001232     0.236757
# state                                     0.001177  0.098272     0.009657
# ProductGroup                              0.012135 -0.013474     0.352182
# ProductGroupDesc                          0.012135 -0.013474     0.352182
# Enclosure                                -0.008816 -0.008743    -0.055898
# Forks                                     0.005022  0.002693     0.060171
# Ride_Control                              0.012073  0.004326     0.098542
# Transmission                              0.004321 -0.002404     0.164341
# Hydraulics                                0.002695 -0.011911     0.069765
# Coupler                                  -0.001735 -0.002822    -0.081867
#
#                           ...  fiProductClassDesc     state  ProductGroup  \
# SalesID                   ...           -0.000780  0.017688      0.015079
# SalePrice                 ...            0.135842 -0.018149      0.235409
# MachineID                 ...           -0.031352  0.027465     -0.046519
# ModelID                   ...           -0.006304 -0.016361     -0.009325
# datasource                ...            0.001438  0.017481      0.007024
# auctioneerID              ...            0.004856  0.013784     -0.012004
# YearMade                  ...           -0.020429 -0.015067     -0.038945
# MachineHoursCurrentMeter  ...            0.006541  0.001177      0.012135
# saledate                  ...            0.001232  0.098272     -0.013474
# fiModelDesc               ...            0.236757  0.009657      0.352182
# fiBaseModel               ...            0.194859  0.007641      0.313483
# fiSecondaryDesc           ...            0.027924 -0.003455     -0.019663
# ProductSize               ...           -0.287341  0.010703     -0.153100
# fiProductClassDesc        ...            1.000000 -0.032145      0.811247
# state                     ...           -0.032145  1.000000     -0.019989
# ProductGroup              ...            0.811247 -0.019989      1.000000
# ProductGroupDesc          ...            0.811247 -0.019989      1.000000
# Enclosure                 ...            0.129347 -0.038627     -0.135278
# Forks                     ...            0.129710  0.002056      0.109998
# Ride_Control              ...            0.559979 -0.054615      0.529796
# Transmission              ...           -0.049689 -0.011153      0.184084
# Hydraulics                ...           -0.268030  0.008285     -0.042996
# Coupler                   ...           -0.096789  0.019333     -0.151101
#
#                           ProductGroupDesc  Enclosure     Forks  Ride_Control  \
# SalesID                           0.015079  -0.002230  0.035118      0.025605
# SalePrice                         0.235409  -0.185837  0.046784      0.150367
# MachineID                        -0.046519   0.009796 -0.042936     -0.003647
# ModelID                          -0.009325  -0.003698 -0.014144     -0.044937
# datasource                        0.007024  -0.000535  0.043860      0.038444
# auctioneerID                     -0.012004   0.017562 -0.008949     -0.010610
# YearMade                         -0.038945   0.052592  0.025674      0.013150
# MachineHoursCurrentMeter          0.012135  -0.008816  0.005022      0.012073
# saledate                         -0.013474  -0.008743  0.002693      0.004326
# fiModelDesc                       0.352182  -0.055898  0.060171      0.098542
# fiBaseModel                       0.313483  -0.065372  0.061111      0.086209
# fiSecondaryDesc                  -0.019663   0.084883 -0.006916     -0.002515
# ProductSize                      -0.153100  -0.136505 -0.019808     -0.116022
# fiProductClassDesc                0.811247   0.129347  0.129710      0.559979
# state                            -0.019989  -0.038627  0.002056     -0.054615
# ProductGroup                      1.000000  -0.135278  0.109998      0.529796
# ProductGroupDesc                  1.000000  -0.135278  0.109998      0.529796
# Enclosure                        -0.135278   1.000000 -0.024576     -0.131428
# Forks                             0.109998  -0.024576  1.000000      0.281307
# Ride_Control                      0.529796  -0.131428  0.281307      1.000000
# Transmission                      0.184084   0.047656  0.052776      0.134878
# Hydraulics                       -0.042996  -0.261511 -0.123503     -0.322031
# Coupler                          -0.151101   0.071186 -0.235839     -0.177423
#
#                           Transmission  Hydraulics   Coupler
# SalesID                       0.043989   -0.002291 -0.043327
# SalePrice                    -0.159736   -0.020710 -0.081313
# MachineID                     0.078562    0.011942  0.099875
# ModelID                      -0.000389    0.158268 -0.039101
# datasource                    0.056560   -0.039396  0.007262
# auctioneerID                 -0.025735   -0.006920  0.026056
# YearMade                      0.021947   -0.071217 -0.028607
# MachineHoursCurrentMeter      0.004321    0.002695 -0.001735
# saledate                     -0.002404   -0.011911 -0.002822
# fiModelDesc                   0.164341    0.069765 -0.081867
# fiBaseModel                   0.161569    0.090706 -0.091485
# fiSecondaryDesc              -0.027858   -0.196235  0.046483
# ProductSize                  -0.002213    0.192018 -0.007014
# fiProductClassDesc           -0.049689   -0.268030 -0.096789
# state                        -0.011153    0.008285  0.019333
# ProductGroup                  0.184084   -0.042996 -0.151101
# ProductGroupDesc              0.184084   -0.042996 -0.151101
# Enclosure                     0.047656   -0.261511  0.071186
# Forks                         0.052776   -0.123503 -0.235839
# Ride_Control                  0.134878   -0.322031 -0.177423
# Transmission                  1.000000    0.052427 -0.087132
# Hydraulics                    0.052427    1.000000  0.000538
# Coupler                      -0.087132    0.000538  1.000000
#
# [23 rows x 23 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f,ax=plt.subplots(figsize=(20, 20))
sns.heatmap(train_new.corr(), annot=True,center=0, linewidths=.5, fmt='.2%',ax=ax)

# %%
import warnings
warnings.filterwarnings("ignore")
sns.pairplot(train_new,hue='SalePrice')

# %%
from sklearn import preprocessing
trainn=train_new.drop('SalePrice',axis=1)
r_scaler = preprocessing.MinMaxScaler()
r_scaler.fit(trainn)
train1 = pd.DataFrame(r_scaler.transform(trainn), index=trainn.index, columns=trainn.columns)
print(train1.head())
r_scaler1 = preprocessing.MinMaxScaler()
r_scaler1.fit(test_new)
test1 = pd.DataFrame(r_scaler1.transform(test_new), index=test_new.index, columns=test_new.columns)
test1.head()
# Out:
#         SalesID  MachineID   ModelID  datasource  auctioneerID  YearMade  \
# 0  0.000000e+00   0.401833  0.084181         0.0      0.030303  0.991115
# 1  3.850526e-07   0.047322  0.001318         0.0      0.030303  0.983218
# 2  5.775789e-07   0.174879  0.187813         0.0      0.030303  0.988154
# 3  9.626314e-07   0.412845  0.008179         0.0      0.030303  0.988154
# 4  1.347684e-06   0.425275  0.464972         0.0      0.030303  0.994077
#
#    MachineHoursCurrentMeter  saledate  fiModelDesc  fiBaseModel  ...  \
# 0                  0.000027  0.170495     0.189876     0.151360  ...
# 1                  0.001868  0.439510     0.344938     0.269882  ...
# 2                  0.001143  0.352731     0.066026     0.055926  ...
# 3                  0.001404  0.611026     0.734894     0.704977  ...
# 4                  0.000291  0.811383     0.841737     0.783992  ...
#
#    fiProductClassDesc     state  ProductGroup  ProductGroupDesc  Enclosure  \
# 0            0.794521  0.000000           1.0               1.0        0.4
# 1            0.835616  0.615385           1.0               1.0        0.4
# 2            0.520548  0.596154           0.4               0.4        1.0
# 3            0.095890  0.826923           0.6               0.6        0.4
# 4            0.534247  0.596154           0.4               0.4        0.0
#
#    Forks  Ride_Control  Transmission  Hydraulics  Coupler
# 0    0.0           0.5           1.0    0.000000      1.0
# 1    0.0           0.5           1.0    0.000000      1.0
# 2    0.0           0.0           1.0    0.272727      1.0
# 3    0.0           0.0           1.0    0.000000      1.0
# 4    0.0           0.0           1.0    0.272727      1.0
#
# [5 rows x 22 columns]
#         SalesID  MachineID   ModelID  datasource  auctioneerID  YearMade  \
# 0  0.000000e+00   0.363248  0.036267         0.0      0.030303  0.000000
# 1  3.913502e-07   0.421781  0.981947         0.0      0.030303  0.992110
# 2  7.827004e-07   0.402059  0.122656         0.0      0.030303  0.986193
# 3  1.174051e-06   0.427457  0.051817         0.0      0.030303  0.000000
# 4  1.565401e-06   0.415553  0.125723         0.0      0.030303  0.988166
#
#    MachineHoursCurrentMeter  saledate  fiModelDesc  fiBaseModel  ...  \
# 0                  0.000000  0.204301     0.169364     0.154140  ...
# 1                  0.049462  0.204301     0.931214     0.926115  ...
# 2                  0.113531  0.204301     0.092486     0.094268  ...
# 3                  0.052489  0.204301     0.396532     0.314650  ...
# 4                  0.091368  0.193548     0.229480     0.197452  ...
#
#    fiProductClassDesc     state  ProductGroup  ProductGroupDesc  Enclosure  \
# 0            0.333333  0.297872           0.6               0.6   0.000000
# 1            0.212121  0.106383           0.6               0.6   0.666667
# 2            0.196970  0.106383           0.6               0.6   0.666667
# 3            0.212121  0.106383           0.6               0.6   0.000000
# 4            0.787879  0.148936           1.0               1.0   0.666667
#
#    Forks  Ride_Control  Transmission  Hydraulics  Coupler
# 0    0.0           0.0           1.0         1.0      1.0
# 1    0.0           0.0           1.0         0.3      0.0
# 2    0.0           0.0           1.0         0.3      1.0
# 3    0.0           0.0           1.0         1.0      1.0
# 4    0.0           0.5           1.0         0.0      0.5
#
# [5 rows x 22 columns]

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = train1.loc[:,train1.columns!='SalePrice']
y = train_new[['SalePrice']]
selector = SelectKBest(chi2, k=10)
selector.fit(X, y)
X_new = selector.transform(X)
print(X.columns[selector.get_support(indices=True)])
# Out:
# Index(['ModelID', 'auctioneerID', 'YearMade', 'fiProductClassDesc',
#        'ProductGroup', 'ProductGroupDesc', 'Enclosure', 'Forks',
#        'Ride_Control', 'Hydraulics'],
#       dtype='object')

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import confusion_matrix, classification_report 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train=train1[['ModelID','MachineID','auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'Transmission','Coupler','fiProductClassDesc','ProductGroup', 'ProductGroupDesc', 'Enclosure', 'Forks','Ride_Control', 'Hydraulics']]
y_train=train_new['SalePrice']
X_test=test1[['ModelID','MachineID', 'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'Transmission','Coupler','fiProductClassDesc','ProductGroup', 'ProductGroupDesc', 'Enclosure', 'Forks','Ride_Control', 'Hydraulics']]
#X_train,y_train=nm.fit_resample(X_train,y_train)
print(X.shape)
print(y.shape)
# Out:
# (401125, 22)
# (401125, 1)

# %%
gb=GradientBoostingRegressor()
gb.fit(X_train,y_train)
pred=gb.predict(X_test)
cm1=gb.score(X_train,y_train)
print(cm1)
print(pred)
# Out:
# 0.6254785466138255
# [30456.33278352 44904.90857027 40617.48555243 ... 20693.51116975
#  22632.61850725 26881.68301889]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(X_train, y_train)
y_pred = forest_model.predict(X_test)
print(y_pred)
print(round(forest_model.score(X_train, y_train)*100,2))
# Out:
# 87.17

# %%
print(y_pred)
# Out:
# [13227.81547619 46765.06421356 37100.58333333 ...  8870.19390332
#  11616.89880952 11851.20670996]

# %%
from sklearn.tree import DecisionTreeRegressor

dforest_model = DecisionTreeRegressor()
dforest_model.fit(X_train, y_train)
y_pred = dforest_model.predict(X_test)
print(y_pred)
print(round(dforest_model.score(X_train, y_train)*100,2))
# Out:
# [ 7500. 24000. 27000. ...  8000. 12500. 10500.]
# 99.45
